# %%
import pandas as pd
import numpy as np

# %%
megaframe = pd.read_csv("../../../datasets/MEGAFRAME_CLEANEDV2.csv")
idx = megaframe.groupby('REF_AREA')['TIME_PERIOD'].idxmax()
max_rows = megaframe.loc[idx]
max_rows = pd.get_dummies(max_rows, columns=['Region'], dtype=int)


PRESETS = {}
for index, row in max_rows.iterrows():
    dct = dict(row.iloc[3:])
    PRESETS[f"{row['Reference area']} ({row['TIME_PERIOD']})"] = dct
PRESETS
# Out:
# {'Australia (2018)': {'Trade union density': 13.7,
#   'Combined corporate income tax rate': 30.0,
#   'Education spending': 0.0602926128145641,
#   'Health spending': 0.0759744797013351,
#   'Housing spending': 0.002290427501448,
#   'Community development spending': 0.00274830368691,
#   'IRLT': 2.681666666666666,
#   'UNEMP': 5.308814958333333,
#   'Population, total': 24963258.0,
#   'GDP per capita (current US$)': 57196.4220783778,
#   'Inflation, consumer prices (annual %)': 1.91140094445691,
#   'Gini index': 34.3,
#   'Region_East Asia and Pacific': 1,
#   'Region_Europe and Central Asia': 0,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Austria (2019)': {'Trade union density': 26.299999,
#   'Combined corporate income tax rate': 25.0,
#   'Education spending': 0.0483529761191593,
#   'Health spending': 0.0839636127529469,
#   'Housing spending': 0.0009409492791846,
#   'Community development spending': 0.0003721442521693,
#   'IRLT': 0.0629333333333334,
#   'UNEMP': 4.84166666666667,
#   'Population, total': 8879920.0,
#   'GDP per capita (current US$)': 49885.9947355204,
#   'Inflation, consumer prices (annual %)': 1.53089564152644,
#   'Gini index': 30.2,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Belgium (2019)': {'Trade union density': 49.099998,
#   'Combined corporate income tax rate': 29.58,
#   'Education spending': 0.0611966046567593,
#   'Health spending': 0.0745699870829773,
#   'Housing spending': 0.0020221301759597,
#   'Community development spending': 0.0013392571283999,
#   'IRLT': 0.193333333333333,
#   'UNEMP': 5.36666666666667,
#   'Population, total': 11488980.0,
#   'GDP per capita (current US$)': 46716.6227467964,
#   'Inflation, consumer prices (annual %)': 1.43681956996429,
#   'Gini index': 27.2,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Switzerland (2018)': {'Trade union density': 14.4,
#   'Combined corporate income tax rate': 21.148581,
#   'Education spending': 0.0541325099541699,
#   'Health spending': 0.0212316334824989,
#   'Housing spending': 0.0002249243009839,
#   'Community development spending': 0.000620243664246,
#   'IRLT': 0.0331666666666667,
#   'UNEMP': 4.714413963724699,
#   'Population, total': 8514329.0,
#   'GDP per capita (current US$)': 85217.3691512274,
#   'Inflation, consumer prices (annual %)': 0.936335464113563,
#   'Gini index': 33.1,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Colombia (2017)': {'Trade union density': 9.5,
#   'Combined corporate income tax rate': 40.0,
#   'Education spending': 0.0471158243953775,
#   'Health spending': 0.1010456603126516,
#   'Housing spending': 0.0023483345839818,
#   'Community development spending': 1.5435412956007847e-05,
#   'IRLT': 6.771666666666667,
#   'UNEMP': 9.29583333333333,
#   'Population, total': 48131078.0,
#   'GDP per capita (current US$)': 6479.53231292429,
#   'Inflation, consumer prices (annual %)': 4.31431325695011,
#   'Gini index': 49.7,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 0,
#   'Region_Latin America and Caribbean': 1,
#   'Region_Middle East and North Africa': 0},
#  'Costa Rica (2019)': {'Trade union density': 20.5,
#   'Combined corporate income tax rate': 30.0,
#   'Education spending': 0.0751039085733555,
#   'Health spending': 0.0606669578209176,
#   'Housing spending': 0.0033154058329444,
#   'Community development spending': 0.0058580964175498,
#   'IRLT': 10.616666666666664,
#   'UNEMP': 11.755392085,
#   'Population, total': 4999553.0,
#   'GDP per capita (current US$)': 12884.6859951989,
#   'Inflation, consumer prices (annual %)': 2.09604635327807,
#   'Gini index': 48.2,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 0,
#   'Region_Latin America and Caribbean': 1,
#   'Region_Middle East and North Africa': 0},
#  'Czechia (2018)': {'Trade union density': 11.4,
#   'Combined corporate income tax rate': 19.0,
#   'Education spending': 0.043325389858199,
#   'Health spending': 0.0740364876338007,
#   'Housing spending': 0.0017624908848485,
#   'Community development spending': 0.0027197986476064,
#   'IRLT': 1.981123419484392,
#   'UNEMP': 2.26666666666667,
#   'Population, total': 10629928.0,
#   'GDP per capita (current US$)': 23705.9329811299,
#   'Inflation, consumer prices (annual %)': 2.14949494949493,
#   'Gini index': 25.0,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Germany (2019)': {'Trade union density': 16.299999,
#   'Combined corporate income tax rate': 29.937781,
#   'Education spending': 0.0429561965328376,
#   'Health spending': 0.0715676345448771,
#   'Housing spending': 0.0029831281401348,
#   'Community development spending': 0.001954804689268,
#   'IRLT': -0.253634457795785,
#   'UNEMP': 2.975,
#   'Population, total': 83092962.0,
#   'GDP per capita (current US$)': 47623.8656074829,
#   'Inflation, consumer prices (annual %)': 1.44565976888253,
#   'Gini index': 31.8,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Denmark (2019)': {'Trade union density': 67.0,
#   'Combined corporate income tax rate': 22.0,
#   'Education spending': 0.0632064686884425,
#   'Health spending': 0.0873079645369513,
#   'Housing spending': 0.0066007457247973,
#   'Community development spending': 0.0,
#   'IRLT': -0.183416666666667,
#   'UNEMP': 5.025,
#   'Population, total': 5814422.0,
#   'GDP per capita (current US$)': 59404.2663247723,
#   'Inflation, consumer prices (annual %)': 0.75813157251162,
#   'Gini index': 27.7,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Spain (2019)': {'Trade union density': 12.5,
#   'Combined corporate income tax rate': 25.0,
#   'Education spending': 0.0399231082148177,
#   'Health spending': 0.0605538760957468,
#   'Housing spending': 0.0002975169696341,
#   'Community development spending': 0.0003373986009523,
#   'IRLT': 0.661018326902566,
#   'UNEMP': 14.1083333333333,
#   'Population, total': 47134837.0,
#   'GDP per capita (current US$)': 29776.2011500384,
#   'Inflation, consumer prices (annual %)': 0.699518994458739,
#   'Gini index': 34.3,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Finland (2019)': {'Trade union density': 58.799999,
#   'Combined corporate income tax rate': 20.0,
#   'Education spending': 0.0585238849898111,
#   'Health spending': 0.0720909952288704,
#   'Housing spending': 0.0062511005458706,
#   'Community development spending': 0.002008234179391,
#   'IRLT': 0.07,
#   'UNEMP': 6.74166666666667,
#   'Population, total': 5521606.0,
#   'GDP per capita (current US$)': 48358.1807773701,
#   'Inflation, consumer prices (annual %)': 1.02409392963431,
#   'Gini index': 27.7,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'France (2016)': {'Trade union density': 10.8,
#   'Combined corporate income tax rate': 34.433333,
#   'Education spending': 0.0541365537136714,
#   'Health spending': 0.0813358895738529,
#   'Housing spending': 0.0094111566026497,
#   'Community development spending': 0.0058351500874265,
#   'IRLT': 0.4666666666666666,
#   'UNEMP': 10.058333333333334,
#   'Population, total': 66724104.0,
#   'GDP per capita (current US$)': 37024.2157133669,
#   'Inflation, consumer prices (annual %)': 0.18333486112386,
#   'Gini index': 31.9,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'United Kingdom (2019)': {'Trade union density': 23.5,
#   'Combined corporate income tax rate': 19.0,
#   'Education spending': 0.0490250102846071,
#   'Health spending': 0.076439139969587,
#   'Housing spending': 0.0085097011040229,
#   'Community development spending': 0.0036290450736619,
#   'IRLT': 0.935825,
#   'UNEMP': 3.825,
#   'Population, total': 66836327.0,
#   'GDP per capita (current US$)': 42662.5353740311,
#   'Inflation, consumer prices (annual %)': 1.73810460086513,
#   'Gini index': 32.8,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Greece (2016)': {'Trade union density': 19.0,
#   'Combined corporate income tax rate': 29.0,
#   'Education spending': 0.0401666546430402,
#   'Health spending': 0.0533453529482136,
#   'Housing spending': 6.878833391130061e-05,
#   'Community development spending': 5.732361159275049e-06,
#   'IRLT': 8.36,
#   'UNEMP': 23.875,
#   'Population, total': 10775971.0,
#   'GDP per capita (current US$)': 17919.2426377048,
#   'Inflation, consumer prices (annual %)': -0.825653978390973,
#   'Gini index': 35.0,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Hungary (2018)': {'Trade union density': 8.3000002,
#   'Combined corporate income tax rate': 9.0,
#   'Education spending': 0.0500894398307683,
#   'Health spending': 0.0464780804997658,
#   'Housing spending': 0.0007890204166206,
#   'Community development spending': 0.0002875073956978,
#   'IRLT': 3.05833333333333,
#   'UNEMP': 3.4916666666666663,
#   'Population, total': 9775564.0,
#   'GDP per capita (current US$)': 16425.2050299693,
#   'Inflation, consumer prices (annual %)': 2.85024792594646,
#   'Gini index': 29.6,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Ireland (2020)': {'Trade union density': 26.200001,
#   'Combined corporate income tax rate': 12.5,
#   'Education spending': 0.0314951984323029,
#   'Health spending': 0.0538586472122729,
#   'Housing spending': 0.0082486159880801,
#   'Community development spending': 0.0011326318754963,
#   'IRLT': -0.0610416666666666,
#   'UNEMP': 5.858333333333333,
#   'Population, total': 4985382.0,
#   'GDP per capita (current US$)': 87567.1148972037,
#   'Inflation, consumer prices (annual %)': -0.326183651280033,
#   'Gini index': 29.2,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Iceland (2017)': {'Trade union density': 91.0,
#   'Combined corporate income tax rate': 20.0,
#   'Education spending': 0.0699489135413116,
#   'Health spending': 0.0755476293928899,
#   'Housing spending': 0.0041272019469201,
#   'Community development spending': 0.0032574156831149,
#   'IRLT': 2.21583333333333,
#   'UNEMP': 3.2833333333333337,
#   'Population, total': 343400.0,
#   'GDP per capita (current US$)': 72010.1490316258,
#   'Inflation, consumer prices (annual %)': 1.76041559180596,
#   'Gini index': 26.1,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Israel (2017)': {'Trade union density': 25.0,
#   'Combined corporate income tax rate': 24.0,
#   'Education spending': 0.0697944596922351,
#   'Health spending': 0.0526468465238923,
#   'Housing spending': 0.0016337556096935,
#   'Community development spending': 0.0020638697149996,
#   'IRLT': 1.90916666666667,
#   'UNEMP': 4.21666666666667,
#   'Population, total': 8713300.0,
#   'GDP per capita (current US$)': 40997.9110240274,
#   'Inflation, consumer prices (annual %)': 0.25941497450575,
#   'Gini index': 38.2,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 0,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 1},
#  'Italy (2019)': {'Trade union density': 32.5,
#   'Combined corporate income tax rate': 27.8064,
#   'Education spending': 0.0395593444766006,
#   'Health spending': 0.0671122599229682,
#   'Housing spending': 0.0003353534359148,
#   'Community development spending': 0.0016551493547799,
#   'IRLT': 1.9515,
#   'UNEMP': 9.93333333333333,
#   'Population, total': 59729081.0,
#   'GDP per capita (current US$)': 33812.788724868,
#   'Inflation, consumer prices (annual %)': 0.611246943765304,
#   'Gini index': 34.6,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Japan (2013)': {'Trade union density': 17.799999,
#   'Combined corporate income tax rate': 37.0,
#   'Education spending': 0.0360127351923705,
#   'Health spending': 0.0764076157960105,
#   'Housing spending': 6.585406032546458e-05,
#   'Community development spending': 0.0041238402313659,
#   'IRLT': 0.689666666666667,
#   'UNEMP': 4.025,
#   'Population, total': 127445000.0,
#   'GDP per capita (current US$)': 40898.6478964744,
#   'Inflation, consumer prices (annual %)': 0.335037912184741,
#   'Gini index': 32.9,
#   'Region_East Asia and Pacific': 1,
#   'Region_Europe and Central Asia': 0,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Lithuania (2019)': {'Trade union density': 7.4000001,
#   'Combined corporate income tax rate': 15.0,
#   'Education spending': 0.0457460415762357,
#   'Health spending': 0.0502357540784592,
#   'Housing spending': 0.0006649169372723,
#   'Community development spending': 0.0029894860466245,
#   'IRLT': 0.31,
#   'UNEMP': 6.28333333333333,
#   'Population, total': 2794137.0,
#   'GDP per capita (current US$)': 19727.7607453736,
#   'Inflation, consumer prices (annual %)': 2.33450937988027,
#   'Gini index': 35.3,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Luxembourg (2019)': {'Trade union density': 28.200001,
#   'Combined corporate income tax rate': 24.94,
#   'Education spending': 0.0480752281431381,
#   'Health spending': 0.0517909788818393,
#   'Housing spending': 0.0007859810705581,
#   'Community development spending': 0.0015247103751054,
#   'IRLT': -0.120583333333333,
#   'UNEMP': 5.59166666666667,
#   'Population, total': 620001.0,
#   'GDP per capita (current US$)': 112726.439672814,
#   'Inflation, consumer prices (annual %)': 1.74332075653848,
#   'Gini index': 34.2,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Latvia (2018)': {'Trade union density': 11.6,
#   'Combined corporate income tax rate': 20.0,
#   'Education spending': 0.060329743683569,
#   'Health spending': 0.0416126723825565,
#   'Housing spending': 0.0009611613044983,
#   'Community development spending': 0.0036617191012835,
#   'IRLT': 0.9025,
#   'UNEMP': 7.4,
#   'Population, total': 1927174.0,
#   'GDP per capita (current US$)': 17252.1710428626,
#   'Inflation, consumer prices (annual %)': 2.53445424186598,
#   'Gini index': 35.1,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Netherlands (2019)': {'Trade union density': 15.4,
#   'Combined corporate income tax rate': 25.0,
#   'Education spending': 0.0488498578516611,
#   'Health spending': 0.072150374743752,
#   'Housing spending': 0.0043024126049842,
#   'Community development spending': 0.0015016263601709,
#   'IRLT': -0.0701666666666666,
#   'UNEMP': 4.43333333333333,
#   'Population, total': 17344874.0,
#   'GDP per capita (current US$)': 53554.9007491475,
#   'Inflation, consumer prices (annual %)': 2.63369910249601,
#   'Gini index': 29.2,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Norway (2019)': {'Trade union density': 50.400002,
#   'Combined corporate income tax rate': 22.0,
#   'Education spending': 0.0555386430176563,
#   'Health spending': 0.0862369844120149,
#   'Housing spending': 0.0012874843234674,
#   'Community development spending': 0.0,
#   'IRLT': 1.49416666666667,
#   'UNEMP': 3.875,
#   'Population, total': 5347896.0,
#   'GDP per capita (current US$)': 76430.5889473338,
#   'Inflation, consumer prices (annual %)': 2.16773003305402,
#   'Gini index': 27.7,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Poland (2017)': {'Trade union density': 13.4,
#   'Combined corporate income tax rate': 19.0,
#   'Education spending': 0.048813522992945,
#   'Health spending': 0.0466635016592139,
#   'Housing spending': 0.0003903625535562,
#   'Community development spending': 0.000481326458453,
#   'IRLT': 3.42,
#   'UNEMP': 4.95833333333333,
#   'Population, total': 37974826.0,
#   'GDP per capita (current US$)': 13913.3402919927,
#   'Inflation, consumer prices (annual %)': 2.0759355367385,
#   'Gini index': 29.7,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Portugal (2016)': {'Trade union density': 15.3,
#   'Combined corporate income tax rate': 29.5,
#   'Education spending': 0.0477369580696354,
#   'Health spending': 0.0611153783913612,
#   'Housing spending': 0.0023626903656236,
#   'Community development spending': 0.0018257250377291,
#   'IRLT': 3.1725,
#   'UNEMP': 11.475,
#   'Population, total': 10325452.0,
#   'GDP per capita (current US$)': 19980.2808866516,
#   'Inflation, consumer prices (annual %)': 0.607397074641719,
#   'Gini index': 35.2,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Slovak Republic (2018)': {'Trade union density': 11.3,
#   'Combined corporate income tax rate': 21.0,
#   'Education spending': 0.0417350815114434,
#   'Health spending': 0.0544850028608415,
#   'Housing spending': 0.0031623074923989,
#   'Community development spending': 0.0022491064636986,
#   'IRLT': 0.885511,
#   'UNEMP': 6.50833333333333,
#   'Population, total': 5446771.0,
#   'GDP per capita (current US$)': 19573.3717031314,
#   'Inflation, consumer prices (annual %)': 2.51403712883812,
#   'Gini index': 25.0,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Slovenia (2015)': {'Trade union density': 23.799999,
#   'Combined corporate income tax rate': 17.0,
#   'Education spending': 0.0563224434755114,
#   'Health spending': 0.0672792469849306,
#   'Housing spending': 0.0002395185251602,
#   'Community development spending': 0.0003475876211111,
#   'IRLT': 1.705,
#   'UNEMP': 8.98333333333333,
#   'Population, total': 2063531.0,
#   'GDP per capita (current US$)': 20697.2748530619,
#   'Inflation, consumer prices (annual %)': -0.525552285820877,
#   'Gini index': 25.4,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0},
#  'Sweden (2019)': {'Trade union density': 65.199997,
#   'Combined corporate income tax rate': 21.4,
#   'Education spending': 0.0763503232280567,
#   'Health spending': 0.0714137420449579,
#   'Housing spending': 0.0027422581322565,
#   'Community development spending': 0.0031461566168525,
#   'IRLT': 0.0937583333333333,
#   'UNEMP': 6.90833333333333,
#   'Population, total': 10278887.0,
#   'GDP per capita (current US$)': 51773.0464558993,
#   'Inflation, consumer prices (annual %)': 1.78415097403835,
#   'Gini index': 29.3,
#   'Region_East Asia and Pacific': 0,
#   'Region_Europe and Central Asia': 1,
#   'Region_Latin America and Caribbean': 0,
#   'Region_Middle East and North Africa': 0}}
