# %%
import requests
import pandas as pd
import json
from io import StringIO

def fetch_oecd_data(metric):
    url = f"https://sdmx.oecd.org/public/rest/data/{metric}/all?startPeriod=2000&endPeriod=2025&dimensionAtObservation=AllDimensions&format=csvfilewithlabels"
    response = requests.get(url)
    print(response.status_code)
    # digesting the csv text into a pandas df
    df = pd.read_csv(StringIO(response.text)) #stringio makes it "appear" like a csv to pandas
    #df = df[['TIME_PERIOD', 'Reference area', 'REF_AREA', 'Measure','OBS_VALUE']] # selecting columns to keep
    return df

TradeUnion_code = 'OECD.ELS.SAE,DSD_TUD_CBC@DF_TUD,'
CorpTax_code = 'OECD.CTP.TPS,DSD_TAX_CIT@DF_CIT,1.0/.A..ST..S13+S1311+S13M..'
GovSpend_code = 'OECD.SDD.NAD,DSD_NASEC10@DF_TABLE11,/A..S13...OTE.....V..'

df = fetch_oecd_data(GovSpend_code)
print(df.shape)
#df.to_csv('GovSpend.csv', index=False)
# Out:
# 200
# (63750, 50)

# %%
import requests
import pandas as pd

def fetch_worldbank_gini_data():
    """
    Fetches GINI index data from the World Bank API for selected countries.

    Returns:
        pd.DataFrame: A DataFrame with columns [country, indicator, indicator_name, date, value]
    """

    # GINI index endpoints for specified countries
    endpoints = {
        "USA_GINI": "https://api.worldbank.org/v2/country/usa/indicator/SI.POV.GINI?format=json&per_page=1000",
        "BRA_GINI": "https://api.worldbank.org/v2/country/br/indicator/SI.POV.GINI?format=json&per_page=1000",
        "GBR_GINI": "https://api.worldbank.org/v2/country/gbr/indicator/SI.POV.GINI?format=json&per_page=1000",
        "ARG_GINI": "https://api.worldbank.org/v2/country/arg/indicator/SI.POV.GINI?format=json&per_page=1000",
        "DEU_GINI": "https://api.worldbank.org/v2/country/deu/indicator/SI.POV.GINI?format=json&per_page=1000",
    }

    all_data = []

    for label, url in endpoints.items():
        response = requests.get(url)
        print(f"{label} status: {response.status_code}")

        json_data = response.json()

        # Ensure response has data
        if isinstance(json_data, list) and len(json_data) > 1:
            for entry in json_data[1]:
                all_data.append({
                    "country": entry["country"]["value"],
                    "indicator": entry["indicator"]["id"],
                    "indicator_name": entry["indicator"]["value"],
                    "date": int(entry["date"]),
                    "value": entry["value"]
                })

    df_all = pd.DataFrame(all_data)
    df_all = df_all.sort_values(by=["country", "date"], ascending=[True, False])

    return df_all

# %%
df = fetch_worldbank_gini_data()
print(df.head())
# Out:
# USA_GINI status: 200
# BRA_GINI status: 200
# GBR_GINI status: 200
# ARG_GINI status: 200
# DEU_GINI status: 200
#        country    indicator indicator_name  date  value
# 195  Argentina  SI.POV.GINI     Gini index  2024    NaN
# 196  Argentina  SI.POV.GINI     Gini index  2023    NaN
# 197  Argentina  SI.POV.GINI     Gini index  2022   40.7
# 198  Argentina  SI.POV.GINI     Gini index  2021   42.4
# 199  Argentina  SI.POV.GINI     Gini index  2020   42.7

# %%
# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Now print the full DataFrame
print(df)
# Out:
#             country    indicator indicator_name  date  value
# 195       Argentina  SI.POV.GINI     Gini index  2024    NaN
# 196       Argentina  SI.POV.GINI     Gini index  2023    NaN
# 197       Argentina  SI.POV.GINI     Gini index  2022   40.7
# 198       Argentina  SI.POV.GINI     Gini index  2021   42.4
# 199       Argentina  SI.POV.GINI     Gini index  2020   42.7
# 200       Argentina  SI.POV.GINI     Gini index  2019   43.3
# 201       Argentina  SI.POV.GINI     Gini index  2018   41.7
# 202       Argentina  SI.POV.GINI     Gini index  2017   41.4
# 203       Argentina  SI.POV.GINI     Gini index  2016   42.3
# 204       Argentina  SI.POV.GINI     Gini index  2015    NaN
# 205       Argentina  SI.POV.GINI     Gini index  2014   41.8
# 206       Argentina  SI.POV.GINI     Gini index  2013   41.1
# 207       Argentina  SI.POV.GINI     Gini index  2012   41.4
# 208       Argentina  SI.POV.GINI     Gini index  2011   42.7
# 209       Argentina  SI.POV.GINI     Gini index  2010   43.7
# 210       Argentina  SI.POV.GINI     Gini index  2009   43.8
# 211       Argentina  SI.POV.GINI     Gini index  2008   45.0
# 212       Argentina  SI.POV.GINI     Gini index  2007   46.3
# 213       Argentina  SI.POV.GINI     Gini index  2006   46.4
# 214       Argentina  SI.POV.GINI     Gini index  2005   47.8
# 215       Argentina  SI.POV.GINI     Gini index  2004   48.5
# 216       Argentina  SI.POV.GINI     Gini index  2003   51.0
# 217       Argentina  SI.POV.GINI     Gini index  2002   53.8
# 218       Argentina  SI.POV.GINI     Gini index  2001   53.3
# 219       Argentina  SI.POV.GINI     Gini index  2000   51.0
# 220       Argentina  SI.POV.GINI     Gini index  1999   49.8
# 221       Argentina  SI.POV.GINI     Gini index  1998   50.7
# 222       Argentina  SI.POV.GINI     Gini index  1997   49.1
# 223       Argentina  SI.POV.GINI     Gini index  1996   49.5
# 224       Argentina  SI.POV.GINI     Gini index  1995   48.9
# 225       Argentina  SI.POV.GINI     Gini index  1994   45.9
# 226       Argentina  SI.POV.GINI     Gini index  1993   44.8
# 227       Argentina  SI.POV.GINI     Gini index  1992   45.5
# 228       Argentina  SI.POV.GINI     Gini index  1991   46.8
# 229       Argentina  SI.POV.GINI     Gini index  1990    NaN
# 230       Argentina  SI.POV.GINI     Gini index  1989    NaN
# 231       Argentina  SI.POV.GINI     Gini index  1988    NaN
# 232       Argentina  SI.POV.GINI     Gini index  1987   45.3
# 233       Argentina  SI.POV.GINI     Gini index  1986   42.8
# 234       Argentina  SI.POV.GINI     Gini index  1985    NaN
# 235       Argentina  SI.POV.GINI     Gini index  1984    NaN
# 236       Argentina  SI.POV.GINI     Gini index  1983    NaN
# 237       Argentina  SI.POV.GINI     Gini index  1982    NaN
# 238       Argentina  SI.POV.GINI     Gini index  1981    NaN
# 239       Argentina  SI.POV.GINI     Gini index  1980   40.8
# 240       Argentina  SI.POV.GINI     Gini index  1979    NaN
# 241       Argentina  SI.POV.GINI     Gini index  1978    NaN
# 242       Argentina  SI.POV.GINI     Gini index  1977    NaN
# 243       Argentina  SI.POV.GINI     Gini index  1976    NaN
# 244       Argentina  SI.POV.GINI     Gini index  1975    NaN
# 245       Argentina  SI.POV.GINI     Gini index  1974    NaN
# 246       Argentina  SI.POV.GINI     Gini index  1973    NaN
# 247       Argentina  SI.POV.GINI     Gini index  1972    NaN
# 248       Argentina  SI.POV.GINI     Gini index  1971    NaN
# 249       Argentina  SI.POV.GINI     Gini index  1970    NaN
# 250       Argentina  SI.POV.GINI     Gini index  1969    NaN
# 251       Argentina  SI.POV.GINI     Gini index  1968    NaN
# 252       Argentina  SI.POV.GINI     Gini index  1967    NaN
# 253       Argentina  SI.POV.GINI     Gini index  1966    NaN
# 254       Argentina  SI.POV.GINI     Gini index  1965    NaN
# 255       Argentina  SI.POV.GINI     Gini index  1964    NaN
# 256       Argentina  SI.POV.GINI     Gini index  1963    NaN
# 257       Argentina  SI.POV.GINI     Gini index  1962    NaN
# 258       Argentina  SI.POV.GINI     Gini index  1961    NaN
# 259       Argentina  SI.POV.GINI     Gini index  1960    NaN
# 65           Brazil  SI.POV.GINI     Gini index  2024    NaN
# 66           Brazil  SI.POV.GINI     Gini index  2023    NaN
# 67           Brazil  SI.POV.GINI     Gini index  2022   52.0
# 68           Brazil  SI.POV.GINI     Gini index  2021   52.9
# 69           Brazil  SI.POV.GINI     Gini index  2020   48.9
# 70           Brazil  SI.POV.GINI     Gini index  2019   53.5
# 71           Brazil  SI.POV.GINI     Gini index  2018   53.9
# 72           Brazil  SI.POV.GINI     Gini index  2017   53.3
# 73           Brazil  SI.POV.GINI     Gini index  2016   53.4
# 74           Brazil  SI.POV.GINI     Gini index  2015   51.9
# 75           Brazil  SI.POV.GINI     Gini index  2014   52.0
# 76           Brazil  SI.POV.GINI     Gini index  2013   52.7
# 77           Brazil  SI.POV.GINI     Gini index  2012   53.4
# 78           Brazil  SI.POV.GINI     Gini index  2011   52.9
# 79           Brazil  SI.POV.GINI     Gini index  2010    NaN
# 80           Brazil  SI.POV.GINI     Gini index  2009   53.7
# 81           Brazil  SI.POV.GINI     Gini index  2008   54.0
# 82           Brazil  SI.POV.GINI     Gini index  2007   54.9
# 83           Brazil  SI.POV.GINI     Gini index  2006   55.6
# 84           Brazil  SI.POV.GINI     Gini index  2005   56.3
# 85           Brazil  SI.POV.GINI     Gini index  2004   56.5
# 86           Brazil  SI.POV.GINI     Gini index  2003   57.6
# 87           Brazil  SI.POV.GINI     Gini index  2002   58.1
# 88           Brazil  SI.POV.GINI     Gini index  2001   58.4
# 89           Brazil  SI.POV.GINI     Gini index  2000    NaN
# 90           Brazil  SI.POV.GINI     Gini index  1999   59.0
# 91           Brazil  SI.POV.GINI     Gini index  1998   59.6
# 92           Brazil  SI.POV.GINI     Gini index  1997   59.8
# 93           Brazil  SI.POV.GINI     Gini index  1996   59.8
# 94           Brazil  SI.POV.GINI     Gini index  1995   59.5
# 95           Brazil  SI.POV.GINI     Gini index  1994    NaN
# 96           Brazil  SI.POV.GINI     Gini index  1993   60.1
# 97           Brazil  SI.POV.GINI     Gini index  1992   53.1
# 98           Brazil  SI.POV.GINI     Gini index  1991    NaN
# 99           Brazil  SI.POV.GINI     Gini index  1990   60.4
# 100          Brazil  SI.POV.GINI     Gini index  1989   63.2
# 101          Brazil  SI.POV.GINI     Gini index  1988   61.4
# 102          Brazil  SI.POV.GINI     Gini index  1987   59.6
# 103          Brazil  SI.POV.GINI     Gini index  1986   58.4
# 104          Brazil  SI.POV.GINI     Gini index  1985   55.5
# 105          Brazil  SI.POV.GINI     Gini index  1984   58.3
# 106          Brazil  SI.POV.GINI     Gini index  1983   58.9
# 107          Brazil  SI.POV.GINI     Gini index  1982   58.4
# 108          Brazil  SI.POV.GINI     Gini index  1981   57.9
# 109          Brazil  SI.POV.GINI     Gini index  1980    NaN
# 110          Brazil  SI.POV.GINI     Gini index  1979    NaN
# 111          Brazil  SI.POV.GINI     Gini index  1978    NaN
# 112          Brazil  SI.POV.GINI     Gini index  1977    NaN
# 113          Brazil  SI.POV.GINI     Gini index  1976    NaN
# 114          Brazil  SI.POV.GINI     Gini index  1975    NaN
# 115          Brazil  SI.POV.GINI     Gini index  1974    NaN
# 116          Brazil  SI.POV.GINI     Gini index  1973    NaN
# 117          Brazil  SI.POV.GINI     Gini index  1972    NaN
# 118          Brazil  SI.POV.GINI     Gini index  1971    NaN
# 119          Brazil  SI.POV.GINI     Gini index  1970    NaN
# 120          Brazil  SI.POV.GINI     Gini index  1969    NaN
# 121          Brazil  SI.POV.GINI     Gini index  1968    NaN
# 122          Brazil  SI.POV.GINI     Gini index  1967    NaN
# 123          Brazil  SI.POV.GINI     Gini index  1966    NaN
# 124          Brazil  SI.POV.GINI     Gini index  1965    NaN
# 125          Brazil  SI.POV.GINI     Gini index  1964    NaN
# 126          Brazil  SI.POV.GINI     Gini index  1963    NaN
# 127          Brazil  SI.POV.GINI     Gini index  1962    NaN
# 128          Brazil  SI.POV.GINI     Gini index  1961    NaN
# 129          Brazil  SI.POV.GINI     Gini index  1960    NaN
# 260         Germany  SI.POV.GINI     Gini index  2024    NaN
# 261         Germany  SI.POV.GINI     Gini index  2023    NaN
# 262         Germany  SI.POV.GINI     Gini index  2022    NaN
# 263         Germany  SI.POV.GINI     Gini index  2021    NaN
# 264         Germany  SI.POV.GINI     Gini index  2020   32.4
# 265         Germany  SI.POV.GINI     Gini index  2019   31.8
# 266         Germany  SI.POV.GINI     Gini index  2018   31.9
# 267         Germany  SI.POV.GINI     Gini index  2017   31.3
# 268         Germany  SI.POV.GINI     Gini index  2016   31.4
# 269         Germany  SI.POV.GINI     Gini index  2015   31.7
# 270         Germany  SI.POV.GINI     Gini index  2014   30.8
# 271         Germany  SI.POV.GINI     Gini index  2013   31.5
# 272         Germany  SI.POV.GINI     Gini index  2012   31.1
# 273         Germany  SI.POV.GINI     Gini index  2011   30.6
# 274         Germany  SI.POV.GINI     Gini index  2010   30.2
# 275         Germany  SI.POV.GINI     Gini index  2009   30.5
# 276         Germany  SI.POV.GINI     Gini index  2008   30.8
# 277         Germany  SI.POV.GINI     Gini index  2007   31.2
# 278         Germany  SI.POV.GINI     Gini index  2006   31.0
# 279         Germany  SI.POV.GINI     Gini index  2005   31.7
# 280         Germany  SI.POV.GINI     Gini index  2004   30.2
# 281         Germany  SI.POV.GINI     Gini index  2003   29.8
# 282         Germany  SI.POV.GINI     Gini index  2002   29.8
# 283         Germany  SI.POV.GINI     Gini index  2001   29.9
# 284         Germany  SI.POV.GINI     Gini index  2000   28.9
# 285         Germany  SI.POV.GINI     Gini index  1999   29.0
# 286         Germany  SI.POV.GINI     Gini index  1998   28.3
# 287         Germany  SI.POV.GINI     Gini index  1997   28.2
# 288         Germany  SI.POV.GINI     Gini index  1996   28.0
# 289         Germany  SI.POV.GINI     Gini index  1995   28.8
# 290         Germany  SI.POV.GINI     Gini index  1994   29.2
# 291         Germany  SI.POV.GINI     Gini index  1993   28.6
# 292         Germany  SI.POV.GINI     Gini index  1992   29.1
# 293         Germany  SI.POV.GINI     Gini index  1991   29.5
# 294         Germany  SI.POV.GINI     Gini index  1990    NaN
# 295         Germany  SI.POV.GINI     Gini index  1989    NaN
# 296         Germany  SI.POV.GINI     Gini index  1988    NaN
# 297         Germany  SI.POV.GINI     Gini index  1987    NaN
# 298         Germany  SI.POV.GINI     Gini index  1986    NaN
# 299         Germany  SI.POV.GINI     Gini index  1985    NaN
# 300         Germany  SI.POV.GINI     Gini index  1984    NaN
# 301         Germany  SI.POV.GINI     Gini index  1983    NaN
# 302         Germany  SI.POV.GINI     Gini index  1982    NaN
# 303         Germany  SI.POV.GINI     Gini index  1981    NaN
# 304         Germany  SI.POV.GINI     Gini index  1980    NaN
# 305         Germany  SI.POV.GINI     Gini index  1979    NaN
# 306         Germany  SI.POV.GINI     Gini index  1978    NaN
# 307         Germany  SI.POV.GINI     Gini index  1977    NaN
# 308         Germany  SI.POV.GINI     Gini index  1976    NaN
# 309         Germany  SI.POV.GINI     Gini index  1975    NaN
# 310         Germany  SI.POV.GINI     Gini index  1974    NaN
# 311         Germany  SI.POV.GINI     Gini index  1973    NaN
# 312         Germany  SI.POV.GINI     Gini index  1972    NaN
# 313         Germany  SI.POV.GINI     Gini index  1971    NaN
# 314         Germany  SI.POV.GINI     Gini index  1970    NaN
# 315         Germany  SI.POV.GINI     Gini index  1969    NaN
# 316         Germany  SI.POV.GINI     Gini index  1968    NaN
# 317         Germany  SI.POV.GINI     Gini index  1967    NaN
# 318         Germany  SI.POV.GINI     Gini index  1966    NaN
# 319         Germany  SI.POV.GINI     Gini index  1965    NaN
# 320         Germany  SI.POV.GINI     Gini index  1964    NaN
# 321         Germany  SI.POV.GINI     Gini index  1963    NaN
# 322         Germany  SI.POV.GINI     Gini index  1962    NaN
# 323         Germany  SI.POV.GINI     Gini index  1961    NaN
# 324         Germany  SI.POV.GINI     Gini index  1960    NaN
# 130  United Kingdom  SI.POV.GINI     Gini index  2024    NaN
# 131  United Kingdom  SI.POV.GINI     Gini index  2023    NaN
# 132  United Kingdom  SI.POV.GINI     Gini index  2022    NaN
# 133  United Kingdom  SI.POV.GINI     Gini index  2021   32.4
# 134  United Kingdom  SI.POV.GINI     Gini index  2020   32.6
# 135  United Kingdom  SI.POV.GINI     Gini index  2019   32.8
# 136  United Kingdom  SI.POV.GINI     Gini index  2018   33.7
# 137  United Kingdom  SI.POV.GINI     Gini index  2017   32.6
# 138  United Kingdom  SI.POV.GINI     Gini index  2016   33.1
# 139  United Kingdom  SI.POV.GINI     Gini index  2015   33.3
# 140  United Kingdom  SI.POV.GINI     Gini index  2014   33.1
# 141  United Kingdom  SI.POV.GINI     Gini index  2013   32.7
# 142  United Kingdom  SI.POV.GINI     Gini index  2012   33.1
# 143  United Kingdom  SI.POV.GINI     Gini index  2011   33.2
# 144  United Kingdom  SI.POV.GINI     Gini index  2010   33.7
# 145  United Kingdom  SI.POV.GINI     Gini index  2009   35.1
# 146  United Kingdom  SI.POV.GINI     Gini index  2008   35.4
# 147  United Kingdom  SI.POV.GINI     Gini index  2007   34.4
# 148  United Kingdom  SI.POV.GINI     Gini index  2006   35.9
# 149  United Kingdom  SI.POV.GINI     Gini index  2005   35.5
# 150  United Kingdom  SI.POV.GINI     Gini index  2004   34.8
# 151  United Kingdom  SI.POV.GINI     Gini index  2003   34.9
# 152  United Kingdom  SI.POV.GINI     Gini index  2002   35.1
# 153  United Kingdom  SI.POV.GINI     Gini index  2001   37.1
# 154  United Kingdom  SI.POV.GINI     Gini index  2000   38.8
# 155  United Kingdom  SI.POV.GINI     Gini index  1999   36.8
# 156  United Kingdom  SI.POV.GINI     Gini index  1998   36.6
# 157  United Kingdom  SI.POV.GINI     Gini index  1997   35.7
# 158  United Kingdom  SI.POV.GINI     Gini index  1996   35.3
# 159  United Kingdom  SI.POV.GINI     Gini index  1995   35.5
# 160  United Kingdom  SI.POV.GINI     Gini index  1994   36.0
# 161  United Kingdom  SI.POV.GINI     Gini index  1993   35.1
# 162  United Kingdom  SI.POV.GINI     Gini index  1992   35.0
# 163  United Kingdom  SI.POV.GINI     Gini index  1991   35.0
# 164  United Kingdom  SI.POV.GINI     Gini index  1990   35.7
# 165  United Kingdom  SI.POV.GINI     Gini index  1989   33.4
# 166  United Kingdom  SI.POV.GINI     Gini index  1988   34.3
# 167  United Kingdom  SI.POV.GINI     Gini index  1987   33.9
# 168  United Kingdom  SI.POV.GINI     Gini index  1986   31.9
# 169  United Kingdom  SI.POV.GINI     Gini index  1985   30.4
# 170  United Kingdom  SI.POV.GINI     Gini index  1984   29.2
# 171  United Kingdom  SI.POV.GINI     Gini index  1983   29.8
# 172  United Kingdom  SI.POV.GINI     Gini index  1982   29.9
# 173  United Kingdom  SI.POV.GINI     Gini index  1981   29.7
# 174  United Kingdom  SI.POV.GINI     Gini index  1980   28.5
# 175  United Kingdom  SI.POV.GINI     Gini index  1979   27.4
# 176  United Kingdom  SI.POV.GINI     Gini index  1978   27.2
# 177  United Kingdom  SI.POV.GINI     Gini index  1977   27.1
# 178  United Kingdom  SI.POV.GINI     Gini index  1976   27.6
# 179  United Kingdom  SI.POV.GINI     Gini index  1975   27.9
# 180  United Kingdom  SI.POV.GINI     Gini index  1974   29.0
# 181  United Kingdom  SI.POV.GINI     Gini index  1973   28.8
# 182  United Kingdom  SI.POV.GINI     Gini index  1972   28.8
# 183  United Kingdom  SI.POV.GINI     Gini index  1971   29.3
# 184  United Kingdom  SI.POV.GINI     Gini index  1970   28.0
# 185  United Kingdom  SI.POV.GINI     Gini index  1969   27.9
# 186  United Kingdom  SI.POV.GINI     Gini index  1968   26.8
# 187  United Kingdom  SI.POV.GINI     Gini index  1967    NaN
# 188  United Kingdom  SI.POV.GINI     Gini index  1966    NaN
# 189  United Kingdom  SI.POV.GINI     Gini index  1965    NaN
# 190  United Kingdom  SI.POV.GINI     Gini index  1964    NaN
# 191  United Kingdom  SI.POV.GINI     Gini index  1963    NaN
# 192  United Kingdom  SI.POV.GINI     Gini index  1962    NaN
# 193  United Kingdom  SI.POV.GINI     Gini index  1961    NaN
# 194  United Kingdom  SI.POV.GINI     Gini index  1960    NaN
# 0     United States  SI.POV.GINI     Gini index  2024    NaN
# 1     United States  SI.POV.GINI     Gini index  2023    NaN
# 2     United States  SI.POV.GINI     Gini index  2022   41.3
# 3     United States  SI.POV.GINI     Gini index  2021   39.7
# 4     United States  SI.POV.GINI     Gini index  2020   39.7
# 5     United States  SI.POV.GINI     Gini index  2019   41.5
# 6     United States  SI.POV.GINI     Gini index  2018   41.4
# 7     United States  SI.POV.GINI     Gini index  2017   41.2
# 8     United States  SI.POV.GINI     Gini index  2016   41.1
# 9     United States  SI.POV.GINI     Gini index  2015   41.2
# 10    United States  SI.POV.GINI     Gini index  2014   41.5
# 11    United States  SI.POV.GINI     Gini index  2013   40.6
# 12    United States  SI.POV.GINI     Gini index  2012   40.9
# 13    United States  SI.POV.GINI     Gini index  2011   40.9
# 14    United States  SI.POV.GINI     Gini index  2010   40.0
# 15    United States  SI.POV.GINI     Gini index  2009   40.6
# 16    United States  SI.POV.GINI     Gini index  2008   40.8
# 17    United States  SI.POV.GINI     Gini index  2007   40.8
# 18    United States  SI.POV.GINI     Gini index  2006   41.4
# 19    United States  SI.POV.GINI     Gini index  2005   41.0
# 20    United States  SI.POV.GINI     Gini index  2004   40.3
# 21    United States  SI.POV.GINI     Gini index  2003   40.8
# 22    United States  SI.POV.GINI     Gini index  2002   40.4
# 23    United States  SI.POV.GINI     Gini index  2001   40.6
# 24    United States  SI.POV.GINI     Gini index  2000   40.1
# 25    United States  SI.POV.GINI     Gini index  1999   40.0
# 26    United States  SI.POV.GINI     Gini index  1998   40.0
# 27    United States  SI.POV.GINI     Gini index  1997   40.5
# 28    United States  SI.POV.GINI     Gini index  1996   40.3
# 29    United States  SI.POV.GINI     Gini index  1995   39.9
# 30    United States  SI.POV.GINI     Gini index  1994   40.0
# 31    United States  SI.POV.GINI     Gini index  1993   40.4
# 32    United States  SI.POV.GINI     Gini index  1992   38.4
# 33    United States  SI.POV.GINI     Gini index  1991   38.0
# 34    United States  SI.POV.GINI     Gini index  1990   38.3
# 35    United States  SI.POV.GINI     Gini index  1989   38.2
# 36    United States  SI.POV.GINI     Gini index  1988   37.7
# 37    United States  SI.POV.GINI     Gini index  1987   37.2
# 38    United States  SI.POV.GINI     Gini index  1986   37.6
# 39    United States  SI.POV.GINI     Gini index  1985   37.6
# 40    United States  SI.POV.GINI     Gini index  1984   37.3
# 41    United States  SI.POV.GINI     Gini index  1983   37.3
# 42    United States  SI.POV.GINI     Gini index  1982   36.7
# 43    United States  SI.POV.GINI     Gini index  1981   35.5
# 44    United States  SI.POV.GINI     Gini index  1980   34.7
# 45    United States  SI.POV.GINI     Gini index  1979   34.8
# 46    United States  SI.POV.GINI     Gini index  1978   34.8
# 47    United States  SI.POV.GINI     Gini index  1977   35.5
# 48    United States  SI.POV.GINI     Gini index  1976   35.6
# 49    United States  SI.POV.GINI     Gini index  1975   35.6
# 50    United States  SI.POV.GINI     Gini index  1974   35.5
# 51    United States  SI.POV.GINI     Gini index  1973   36.1
# 52    United States  SI.POV.GINI     Gini index  1972   36.7
# 53    United States  SI.POV.GINI     Gini index  1971   36.9
# 54    United States  SI.POV.GINI     Gini index  1970   36.6
# 55    United States  SI.POV.GINI     Gini index  1969   36.0
# 56    United States  SI.POV.GINI     Gini index  1968   36.3
# 57    United States  SI.POV.GINI     Gini index  1967   36.9
# 58    United States  SI.POV.GINI     Gini index  1966   37.8
# 59    United States  SI.POV.GINI     Gini index  1965   37.5
# 60    United States  SI.POV.GINI     Gini index  1964   38.1
# 61    United States  SI.POV.GINI     Gini index  1963   37.6
# 62    United States  SI.POV.GINI     Gini index  1962    NaN
# 63    United States  SI.POV.GINI     Gini index  1961    NaN
# 64    United States  SI.POV.GINI     Gini index  1960    NaN
